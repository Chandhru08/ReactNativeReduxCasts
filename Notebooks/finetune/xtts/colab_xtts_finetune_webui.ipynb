# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandhru08/ReactNativeReduxCasts/blob/master/Notebooks/finetune/xtts/colab_xtts_finetune_webui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Welcome to the *xtts*-finetune-webui gradio gui!
#
# This webui is a slightly modified copy of the official webui for finetune xtts.
#
# If you are looking for an option for normal XTTS use look here https://github.com/daswer123/xtts-webui

# %%
import os

# @title 🛠️ Install requirments
#!DEBIAN_FRONTEND=noninteractive
# !sudo apt-get update
# !sudo apt-get -y install libegl1
# !sudo apt-get -y install libopengl0
# !sudo apt-get -y install libxcb-cursor0

# Install core webui requirements (excluding coqui-tts and faster_whisper, which are installed later with torch/torchaudio)
# !pip install gradio==4.44.1
# !pip install fastapi==0.103.1
# !pip install pydantic==1.10.13

# Install other requirements from the original repo's requirements.txt
# !pip install spacy==3.7.5 cutlet==0.5.0 fugashi[unidic-lite]==1.4.0

# More requirements
# !nvcc --version #check cuda version if things break
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 133 kB in 1s (121 kB/s)
# Reading package lists... Done
# ...

# %%
pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 757.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 104.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 64.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 21.2 MB/s eta 0:00:00
# ...

# %%
pip install torchaudio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 44.2 MB/s eta 0:00:00
# ...

# %%
pip install faster_whisper
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 25.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 85.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.5 MB/s eta 0:00:00
# ...

# %%
# Install coqui-tts after torch and torchaudio are installed
# !pip install coqui-tts[languages]==0.24.2
# Out:
# ...
#   Using cached coqui_tts-0.24.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# ...
#   Using cached anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached coqui_tts_trainer-0.1.4-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached coqpit-0.0.17-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached gruut-2.4.0.tar.gz (85 kB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 70.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 133.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# @title 🚀 Run interface
# %cd /content/

# Remove existing directory to ensure a clean clone
# !rm -rf /content/xtts-finetune-webui
# !git clone https://github.com/DrewThomasson/xtts-finetune-webui.git
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share
# Out:
# /content
# Cloning into 'xtts-finetune-webui'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 277 (delta 109), reused 79 (delta 79), pack-reused 149 (from 3)
# Receiving objects: 100% (277/277), 131.82 KiB | 16.48 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# /content/xtts-finetune-webui
# Traceback (most recent call last):
#   File "/content/xtts-finetune-webui/xtts_demo.py", line 17, in <module>
#     from utils.formatter import format_audio_list,find_latest_best_model, list_audios
#   File "/content/xtts-finetune-webui/utils/formatter.py", line 5, in <module>
#     from faster_whisper import WhisperModel
# ModuleNotFoundError: No module named 'faster_whisper'

# %%
import shutil
import requests
import os
from tqdm import tqdm  # Progress bar library

# Define the paths
finetune_dir = '/content/xtts-finetune-webui/finetune_models/ready'  # @param {type:"string"}
dataset_dir = '/content/xtts-finetune-webui/finetune_models/dataset'  # @param {type:"string"}

# Create a temporary directory to collect both folders before zipping
temp_dir = "/content/temp_finetune_dataset"
os.makedirs(temp_dir, exist_ok=True)

# Copy both directories into the temporary directory with a progress bar
def copy_with_progress(src, dst):
    total_files = sum(len(files) for _, _, files in os.walk(src))
    with tqdm(total=total_files, desc=f"Copying {os.path.basename(src)}") as pbar:
        for root, _, files in os.walk(src):
            rel_path = os.path.relpath(root, src)
            target_path = os.path.join(dst, rel_path)
            os.makedirs(target_path, exist_ok=True)
            for file in files:
                shutil.copy(os.path.join(root, file), target_path)
                pbar.update(1)

copy_with_progress(finetune_dir, os.path.join(temp_dir, "ready"))
copy_with_progress(dataset_dir, os.path.join(temp_dir, "dataset"))

# Create a zip file of the combined directories with progress
zip_filename = "finetune_and_dataset.zip"
with tqdm(total=100, desc="Zipping files") as pbar:
    shutil.make_archive("finetune_and_dataset", 'zip', root_dir=temp_dir)
    pbar.update(100)

# Define a function to stream the upload with a progress bar
def upload_with_progress(file_path, url):
    file_size = os.path.getsize(file_path)
    with open(file_path, 'rb') as f, tqdm(
        total=file_size, unit='B', unit_scale=True, desc="Uploading"
    ) as progress:
        response = requests.post(
            url,
            files={"file": (file_path, f)},
            stream=True,
            headers={"Connection": "keep-alive"},
        )
        # Update the progress bar as chunks are sent
        for chunk in response.iter_content(chunk_size=4096):
            if chunk:
                progress.update(len(chunk))
    return response

# Upload the zip file to file.io with a progress bar
response = upload_with_progress(zip_filename, "https://file.io/?expires=1d")

# Parse the response and display the download link
if response.status_code == 200:
    download_link = response.json().get('link', 'Error: No link found.')
    print(f"Your file is ready: {download_link}")
else:
    print(f"Failed to upload: {response.status_code} - {response.text}")

# %% [markdown]
# # Task
# It seems there's a dependency conflict with `pydantic`. The previous `install_requirements` cell explicitly installed `pydantic==1.10.13`, but `gradio==4.44.1` requires `pydantic>=2.0`, leading to an incompatibility. This is likely causing the `TypeError` observed when running the `xtts_demo.py` script.
#
# To resolve this, I will upgrade `pydantic` to a version that satisfies both `gradio`'s requirement (`>=2.0`) and `spacy`'s requirement (`<3.0.0`). I'll then retry running the web UI.
#
# ```python
# # Upgrade pydantic to a version compatible with gradio and spacy.
# # Gradio 4.44.1 requires pydantic>=2.0.
# # Spacy 3.7.5 requires pydantic<3.0.0,>=1.7.4.
# # Many other packages (e.g., google-genai, langchain) require pydantic>=2.9.0 or higher within the 2.x range.
# # We will upgrade pydantic to the latest 2.x version to satisfy all these requirements.
# !pip install --upgrade pydantic "pydantic<3.0.0" "pydantic>=2.0"
#
# # Change directory back to the cloned repository and run the web UI
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share
# ```

# %% [markdown]
# ## install_torch
#
# ### Subtask:
# Install torch library.

# %% [markdown]
# ## install_faster_whisper
#
# ### Subtask:
# Install faster_whisper library.

# %% [markdown]
# The `faster_whisper` library has already been installed in a previous cell (cell `8DjyZ2qs4FCt`).

# %% [markdown]
# ## install_torchaudio
#
# ### Subtask:
# Install torchaudio library.

# %% [markdown]
# **Reasoning**:
# The subtask is to install the `torchaudio` library. This can be done using the `pip install` command.

# %%
pip install torchaudio

# %% [markdown]
# ## Run interface (retry with pydantic upgrade)
#
# ### Subtask:
# Resolve the pydantic dependency conflict and then run the web UI.

# %% [markdown]
# **Reasoning**:
# The subtask requires upgrading pydantic to resolve dependency conflicts and then running the web UI script. These steps will be executed in a single code block as instructed.

# %%
pip install --upgrade pydantic "pydantic<3.0.0" "pydantic>=2.0"
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share
# Out:
#   File "/tmp/ipython-input-4032811581.py", line 1
#     pip install --upgrade pydantic "pydantic<3.0.0" "pydantic>=2.0"
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Reasoning**:
# The previous code failed with a `SyntaxError` because the `pip install` command was missing the `!` prefix to be executed as a shell command within a Python cell. I will add the `!` prefix to `pip install`.

# %%
# !pip install --upgrade pydantic "pydantic<3.0.0" "pydantic>=2.0"
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.4/463.4 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 65.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.6.3
#     Uninstalling pydantic_core-2.6.3:
#       Successfully uninstalled pydantic_core-2.6.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.8.5 requires torchvision>=0.11, which is not installed.
# google-genai 1.49.0 requires anyio<5.0.0,>=4.8.0, but you have anyio 3.7.1 which is incompatible.
# ...

# %% [markdown]
# **Reasoning**:
# The traceback indicates an `AttributeError` from `fastapi.dependencies.utils` after upgrading `pydantic` to version 2. This suggests an incompatibility between the installed `fastapi==0.103.1` and `pydantic` v2. To resolve this, I will upgrade `fastapi` to a more recent version that is compatible with `pydantic` v2 while still satisfying `gradio`'s dependency (`fastapi<1.0`). I will choose `fastapi==0.111.0` and then retry running the web UI.

# %%
import os

# Upgrade fastapi to a version compatible with Pydantic v2
# For example, fastapi==0.111.0 is known to work with Pydantic v2 and is <1.0 as required by gradio.
# !pip install --upgrade fastapi==0.111.0

# Change directory back to the cloned repository and run the web UI
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.7/517.7 kB 34.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 135.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.8/456.8 kB 45.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.27.0
#     Uninstalling starlette-0.27.0:
#       Successfully uninstalled starlette-0.27.0
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.103.1
#     Uninstalling fastapi-0.103.1:
#       Successfully uninstalled fastapi-0.103.1
# ...

# %% [markdown]
# **Reasoning**:
# The persistent `TypeError` in `gradio_client/utils.py` after upgrading `pydantic` and `fastapi` suggests an incompatibility between the installed `gradio==4.44.1` (or its `gradio-client` dependency) and the updated core libraries. To resolve this, I will upgrade `gradio` to its latest version, allowing it to correctly resolve its dependencies, including `gradio-client`, `fastapi`, and `pydantic`, while respecting the `spacy` constraint for `pydantic` (`<3.0.0`).

# %%
import os

# Upgrade gradio to its latest version along with pydantic and fastapi
# This should ensure all related dependencies are compatible.
# !pip install --upgrade gradio fastapi pydantic "pydantic<3.0.0" --no-cache-dir

# Change directory back to the cloned repository and run the web UI
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share

# %% [markdown]
# **Reasoning**:
# The previous attempts to resolve dependency conflicts were unsuccessful. The `TypeError` likely stems from an incompatibility between `gradio` and the updated `pydantic`/`fastapi` versions. By upgrading `gradio` along with `fastapi` and `pydantic` to their latest compatible versions (while respecting the `pydantic<3.0.0` constraint required by `spacy`), we aim to establish a stable environment where the web UI can run without errors.

# %%
import os

# Upgrade gradio to its latest version along with pydantic and fastapi
# This should ensure all related dependencies are compatible.
# !pip install --upgrade gradio fastapi pydantic "pydantic<3.0.0" --no-cache-dir

# Change directory back to the cloned repository and run the web UI
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 190.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.2/109.2 kB 321.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.121.1
#     Uninstalling fastapi-0.121.1:
#       Successfully uninstalled fastapi-0.121.1
# ...
# [Errno 2] No such file or directory: '/content/xtts-finetune-webui'
# /content
# python3: can't open file '/content/xtts_demo.py': [Errno 2] No such file or directory

# %% [markdown]
# **Reasoning**:
# The previous execution failed because the `xtts-finetune-webui` directory was not found. This indicates that the repository needs to be cloned again before attempting to change into the directory and run the script. I will re-clone the repository and then retry the dependency installations and script execution.

# %%
import os

# Remove existing directory to ensure a clean clone
# !rm -rf /content/xtts-finetune-webui
# Clone the repository
# !git clone https://github.com/DrewThomasson/xtts-finetune-webui.git

# Upgrade gradio to its latest version along with pydantic and fastapi
# This should ensure all related dependencies are compatible.
# !pip install --upgrade gradio fastapi pydantic "pydantic<3.0.0" --no-cache-dir

# Change directory back to the cloned repository and run the web UI
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share
# Out:
# Cloning into 'xtts-finetune-webui'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 277 (delta 109), reused 79 (delta 79), pack-reused 149 (from 3)
# Receiving objects: 100% (277/277), 131.82 KiB | 16.48 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 62.3 MB/s eta 0:00:00
# ...
# /content/xtts-finetune-webui
# Traceback (most recent call last):
#   File "/content/xtts-finetune-webui/xtts_demo.py", line 17, in <module>
#     from utils.formatter import format_audio_list,find_latest_best_model, list_audios
#   File "/content/xtts-finetune-webui/utils/formatter.py", line 5, in <module>
#     from faster_whisper import WhisperModel
# ModuleNotFoundError: No module named 'faster_whisper'

# %% [markdown]
# **Reasoning**:
# The previous attempt failed with `ModuleNotFoundError: No module named 'faster_whisper'`. This suggests that `faster_whisper` needs to be installed, or re-installed, after all other dependencies and before running `xtts_demo.py`.

# %%
import os

# Remove existing directory to ensure a clean clone
# !rm -rf /content/xtts-finetune-webui
# Clone the repository
# !git clone https://github.com/DrewThomasson/xtts-finetune-webui.git

# Upgrade gradio to its latest version along with pydantic and fastapi
# This should ensure all related dependencies are compatible.
# !pip install --upgrade gradio fastapi pydantic "pydantic<3.0.0" --no-cache-dir

# Install faster_whisper explicitly
# !pip install faster_whisper

# Change directory back to the cloned repository and run the web UI
# %cd /content/xtts-finetune-webui
# !python xtts_demo.py --share
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: could not create work tree dir 'xtts-finetune-webui': No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# The folder you are executing pip from can no longer be found.
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# The folder you are executing pip from can no longer be found.
# [Errno 2] No such file or directory: '/content/xtts-finetune-webui'
# /content/xtts-finetune-webui
# ...

# %% [markdown]
# **Reasoning**:
# The previous errors indicated issues with the current working directory during `rm -rf` and `git clone`, and a missing `faster_whisper` module. This comprehensive block first ensures a stable working directory (`/content`), then performs a clean clone, and finally reinstalls/upgrades all necessary dependencies in the correct order, explicitly including `faster_whisper` and the specific `coqui-tts` version, before running the web UI.

# %%
import os

# Ensure we are in /content before trying to remove or clone
# %cd /content/

# Remove existing directory to ensure a clean clone
# !rm -rf /content/xtts-finetune-webui
# Clone the repository
# !git clone https://github.com/DrewThomasson/xtts-finetune-webui.git

# Change directory into the cloned repository
# %cd /content/xtts-finetune-webui

# Install core webui requirements and resolve pydantic/fastapi/gradio conflicts
# Using --no-cache-dir to ensure fresh installs
# !pip install --upgrade gradio fastapi pydantic "pydantic<3.0.0" --no-cache-dir

# Install torch, torchaudio, and faster_whisper to ensure they are available
# Note: coqui-tts[languages]==0.24.2 will be installed in a later step
# !pip install torch torchaudio faster_whisper

# Install coqui-tts after torch and torchaudio are installed, and with the specific version
# !pip install coqui-tts[languages]==0.24.2

# Run the web UI
# !python xtts_demo.py --share
# Out:
# /content
# Cloning into 'xtts-finetune-webui'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 277 (delta 109), reused 79 (delta 79), pack-reused 149 (from 3)
# Receiving objects: 100% (277/277), 131.82 KiB | 8.79 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# /content/xtts-finetune-webui
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 278.6 MB/s eta 0:00:00
# ...
# * Running on local URL:  http://127.0.0.1:5003
# * Running on public URL: https://b235c7c3824f10eddf.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)

# %% [markdown]
# ## run_interface
#
# ### Subtask:
# Clone the repository and run the web UI.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Pre-installed Core Libraries**: `torch`, `faster_whisper`, and `torchaudio` were largely found to be pre-installed or already satisfied within the environment, requiring no new installations for these specific steps.
# *   **Initial `pydantic` Conflict**: The primary issue stemmed from a `pydantic` version conflict, where `pydantic==1.10.13` (explicitly installed earlier) clashed with `gradio==4.44.1`'s requirement for `pydantic>=2.0` and `spacy`'s requirement for `pydantic<3.0.0`.
# *   **Iterative Dependency Resolution**:
#     *   Upgrading `pydantic` to a 2.x version (e.g., `2.12.4`) initially led to an `AttributeError` in `fastapi`, indicating an incompatibility.
#     *   Upgrading `fastapi` to `0.111.0` resolved the `fastapi` error but introduced a `TypeError` in `gradio_client`, suggesting `gradio` or its client was incompatible with the updated `pydantic`/`fastapi`.
#     *   Additional issues included `ModuleNotFoundError` for `faster_whisper` and `FileNotFoundError` due to incorrect working directory.
# *   **Successful Environment Stabilization**: The web UI was successfully launched after a comprehensive approach that involved:
#     *   A clean re-clone of the repository.
#     *   Upgrading `gradio`, `fastapi`, and `pydantic` together, explicitly constraining `pydantic<3.0.0`.
#     *   Explicitly installing `torch`, `torchaudio`, `faster_whisper`, and `coqui-tts[languages]==0.24.2`.
# *   **Minor Warnings, No Critical Impact**: Despite several `pip` dependency resolution warnings (e.g., related to `numpy` incompatibility with other packages), these did not prevent the successful execution and launch of the Gradio web UI.
#
# ### Insights or Next Steps
#
# *   Managing inter-dependencies between major libraries like `pydantic`, `gradio`, and `fastapi` requires careful versioning and often an iterative upgrade process, especially when dealing with breaking changes between major versions (e.g., Pydantic v1 to v2).
# *   For future deployments or development, consider using a locked environment (e.g., `conda` or `venv` with `requirements.txt` generated after successful setup) or containerization (e.g., Docker) to ensure reproducible and stable dependency configurations, avoiding similar conflicts.
